# %%
# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
# %matplotlib inline

# %%
# Pull in police shooting information
popo = pd.read_csv('data/PoliceKillingsUS.csv', encoding = "ISO-8859-1")

# %%
# strip whitespace from city name and make the name lowercase
popo.city = popo.city.str.strip()
popo.city = popo.city.str.lower()

# Do the same with state except upper
popo.state = popo.state.str.strip()
popo.state = popo.state.str.upper()

# %%
# Let's see what we're working with
popo.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        shelton    WA                     True       attack
# 1      M    W          aloha    OR                    False       attack
# 2      M    H        wichita    KS                    False        other
# 3      M    W  san francisco    CA                     True       attack
# 4      M    H          evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
# Create new column with combined city&state info to join on
popo['city_and_state'] = popo.city.astype('str') + ', ' + popo.state.astype('str')

# %%
# Be super anal and strip whitespace from city_&_state column
popo.city_and_state = popo.city_and_state.str.strip()

# %%
popo.head(10)
# Out:
#    id                 name      date   manner_of_death       armed   age  \
# 0   3           Tim Elliot  02/01/15              shot         gun  53.0
# 1   4     Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5   John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8      Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9    Michael Rodriguez  04/01/15              shot    nail gun  39.0
# 5  11    Kenneth Joe Brown  04/01/15              shot         gun  18.0
# 6  13  Kenneth Arnold Buck  05/01/15              shot         gun  22.0
# 7  15        Brock Nichols  06/01/15              shot         gun  35.0
# 8  16        Autumn Steele  06/01/15              shot     unarmed  34.0
# 9  17      Leslie Sapp III  06/01/15              shot  toy weapon  47.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        shelton    WA                     True       attack
# 1      M    W          aloha    OR                    False       attack
# 2      M    H        wichita    KS                    False        other
# 3      M    W  san francisco    CA                     True       attack
# 4      M    H          evans    CO                    False       attack
# 5      M    W        guthrie    OK                    False       attack
# 6      M    H       chandler    AZ                    False       attack
# 7      M    W        assaria    KS                    False       attack
# 8      F    W     burlington    IA                    False        other
# 9      M    B      knoxville    PA                    False       attack
#
#           flee  body_camera     city_and_state
# 0  Not fleeing        False        shelton, WA
# 1  Not fleeing        False          aloha, OR
# 2  Not fleeing        False        wichita, KS
# 3  Not fleeing        False  san francisco, CA
# 4  Not fleeing        False          evans, CO
# 5  Not fleeing        False        guthrie, OK
# 6          Car        False       chandler, AZ
# 7  Not fleeing        False        assaria, KS
# 8  Not fleeing         True     burlington, IA
# 9  Not fleeing        False      knoxville, PA

# %%
# Pull in city to county mapping
city_county_map = pd.read_pickle('data/clean_city_county.pkl')

# %%
# Let's check it out!
city_county_map.head()
# Out:
#              city      city_ascii state_id  state_name  county_fips  \
# 0   prairie ridge   Prairie Ridge       WA  Washington        53053
# 1          edison          Edison       WA  Washington        53057
# 2        packwood        Packwood       WA  Washington        53041
# 3  wautauga beach  Wautauga Beach       WA  Washington        53035
# 4          harper          Harper       WA  Washington        53035
#
#   county_name  density          id      city_and_state
# 0      Pierce   1349.8  1840037882   prairie ridge, WA
# 1      Skagit    127.4  1840017314          edison, WA
# 2       Lewis    213.9  1840025265        packwood, WA
# 3      Kitsap    261.7  1840037725  wautauga beach, WA
# 4      Kitsap    342.1  1840037659          harper, WA

# %%
city_county_map.dtypes
# Out:
# city               object
# city_ascii         object
# state_id           object
# state_name         object
# county_fips         int64
# county_name        object
# density           float64
# id                  int64
# city_and_state     object
# dtype: object

# %%
# grab just the county and city_and_state column from city_county_map
joiner = city_county_map[['county_name', 'city_and_state']]
joiner.dtypes
# Out:
# county_name       object
# city_and_state    object
# dtype: object

# %%
# Let's join the counties onto the shootings dataframe on the city_and_state column
popo2 = pd.merge(popo, joiner,
                left_on = 'city_and_state',
                right_on = 'city_and_state')

# %%
# Check it out:
popo2.head()
# Out:
#     id                  name      date   manner_of_death    armed   age  \
# 0    3            Tim Elliot  02/01/15              shot      gun  53.0
# 1    4      Lewis Lee Lembke  02/01/15              shot      gun  47.0
# 2  890  Phyllis Ilene Jepsen  02/10/15              shot    knife  55.0
# 3    5    John Paul Quintero  03/01/15  shot and Tasered  unarmed  23.0
# 4  765       Nicholas Garner  22/08/15              shot  vehicle  26.0
#
#   gender race     city state  signs_of_mental_illness threat_level  \
# 0      M    A  shelton    WA                     True       attack
# 1      M    W    aloha    OR                    False       attack
# 2      F    W    aloha    OR                     True        other
# 3      M    H  wichita    KS                    False        other
# 4      M    W  wichita    KS                    False       attack
#
#           flee  body_camera city_and_state county_name
# 0  Not fleeing        False    shelton, WA       Mason
# 1  Not fleeing        False      aloha, OR  Washington
# 2  Not fleeing        False      aloha, OR  Washington
# 3  Not fleeing        False    wichita, KS    Sedgwick
# 4          Car        False    wichita, KS    Sedgwick

# %%
# Clean the counties up by deleting '(city)' where it appears
popo2['Counties'] = popo2.county_name.apply(lambda x: ' '.join(x.split()[:-1]) + ' City' \
                                            if x.split()[-1] == '(city)' else x)

# %%
# Reassign the clean column to the old column and drop the clean column 
# (so we have no duplicates)
popo2['county_name'] = popo2['Counties']
popo2.drop(labels = 'Counties', axis = 1, inplace = True)

# %%
# Check to see if '(city)' appears at all
# It shouldn't!
for index, row in popo2.iterrows():
    if 'City' in row.county_name.split():
        print(row.county_name)
# Out:
# Chesapeake City County
# Chesapeake City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Baltimore City County
# Portsmouth City County
# Portsmouth City County
# Winchester City County
# Emporia City County
# Newport News City County
# Newport News City County
# Richmond City County
# Richmond City County
# Richmond City County
# Richmond City County
# Carson City City County
# Carson City City County
# Virginia Beach City County
# Virginia Beach City County
# Harrisonburg City County
# Suffolk City County
# Norfolk City County
# Norfolk City County
# Norfolk City County
# Norfolk City County
# Norfolk City County
# Norfolk City County
# Norfolk City County
# Roanoke City County
# Hopewell City County
# Fredericksburg City County
# Falls Church City County
# Alexandria City County

# %%
# Include the word 'County' at the end of each county name
popo2['county_name'] = popo2.county_name.apply(lambda x: x + ' County')

# %%
popo2.sample(50)
# Out:
#         id                        name      date   manner_of_death  \
# 1791  1696            Thomas Vandemark  06/07/16              shot
# 1628  1412                  Jose Perez  26/03/16              shot
# 624   2806                       TK TK  26/07/17              shot
# 2106  2382          James Leroy Marker  26/02/17              shot
# 1093  2466              Daniel Hendrix  29/03/17              shot
# 1216  2790           Anthony Benavidez  19/07/17              shot
# 328   1518           Deresha Armstrong  05/05/16              shot
# 857    420                Joshua Green  28/04/15              shot
# 1421  1036           Justin D. McHenry  29/11/15              shot
# 1293   868               Jeffrey Blood  25/09/15              shot
# 1906  1950              Maurico Barron  10/10/16              shot
# 2175  2532          Juan Manuel Avilla  25/04/17              shot
# 46    2083       Abdul Razak Ali Artan  28/11/16              shot
# 368    133             Vincent Cordaro  08/02/15              shot
# 1882  1911           Anthony Ray Bauer  26/09/16              shot
# 4      765             Nicholas Garner  22/08/15              shot
# 1355  1634            Sergey Makarenko  18/06/16              shot
# 1660  1479            Demetrius Dorsey  18/04/16              shot
# 1449  1097          Bryant Neil Duncan  16/12/15              shot
# 1650  1458                 Travis Wood  12/04/16              shot
# 1537  2567        Mikel Laney McIntyre  08/05/17              shot
# 1675  2565                       TK TK  09/05/17              shot
# 309   2393                  Earl Riley  28/02/17              shot
# 238    348         Nicolas Leland Tewa  27/01/15              shot
# 2237  2694              Rip Huntington  26/06/17              shot
# 1101  2672             Charleena Lyles  18/06/17              shot
# 881   2557              Jacob Peterson  06/05/17              shot
# 345    128  Paul Alfred Eugene Johnson  05/02/15              shot
# 1587  1331         Travis Boyd Bradley  02/03/16              shot
# 1646  1446           Melissa M. Abbott  08/04/16              shot
# 274   1214            William A. Adams  28/01/16              shot
# 483   2038               John Pacuicrk  10/11/16              shot
# 1763  1662                Josh Herrera  23/06/16              shot
# 1155  2050  Jose George Anthony Franco  16/11/16              shot
# 723   1983               William Frost  21/10/16  shot and Tasered
# 1917  1977             Frank J. Sandor  19/10/16              shot
# 1125  2808           Kesharn K. Burney  26/07/17              shot
# 674    231              Phillip Conley  22/03/15              shot
# 516   2433             Daniel Donarski  16/03/17              shot
# 1359  1593   Christopher Michael Moran  05/06/16              shot
# 1305   889              Christian Pena  02/10/15  shot and Tasered
# 214   1425        Matthew Vincent Wood  31/03/16              shot
# 763    779             Marvin Arroliga  25/08/15              shot
# 829   1522               Lionel Gibson  08/05/16              shot
# 1878  1909                Jesse Ataway  23/09/16              shot
# 2122  2416             Luke O. Stewart  13/03/17              shot
# 2188  2569         Scott N. Bloomfield  09/05/17              shot
# 1959  2080           Norman J. Strobel  27/11/16              shot
# 1627  1406                 Andrew Mike  24/03/16              shot
# 310   2480           Michael Maldonado  04/04/17              shot
#
#              armed   age gender race            city state  \
# 1791           gun  65.0      M    W    rush springs    OK
# 1628  meat cleaver  39.0      M    H          lowell    MA
# 624            gun   NaN      M  NaN     san antonio    TX
# 2106           gun  66.0      M    W     floral city    FL
# 1093           gun  26.0      M    W     chattanooga    TN
# 1216         knife  24.0      M  NaN        santa fe    NM
# 328            gun  26.0      F    B         orlando    FL
# 857            gun  27.0      M    W          marion    IL
# 1421           gun  22.0      M    W          celina    OH
# 1293           gun  45.0      M    W         wilhoit    AZ
# 1906  undetermined  27.0      M    H          irvine    CA
# 2175       vehicle  20.0      M    H      bellflower    CA
# 46           knife  18.0      M    O        columbus    OH
# 368            gun  57.0      M    W        new city    NY
# 1882           gun  52.0      M    W     garden city    ID
# 4          vehicle  26.0      M    W         wichita    KS
# 1355       vehicle  17.0      M    W      carmichael    CA
# 1660           gun  18.0      M    B        mableton    GA
# 1449         knife   NaN      M    W       camarillo    CA
# 1650       vehicle  20.0      M    W            noma    FL
# 1537          rock  32.0      M    B  rancho cordova    CA
# 1675           gun   NaN      M  NaN     westminster    CO
# 309            gun  25.0      M    B         houston    TX
# 238        vehicle  26.0      M    N         phoenix    AZ
# 2237           gun  36.0      M  NaN            rowe    NM
# 1101         knife  30.0      F    B         seattle    WA
# 881     toy weapon  15.0      M    W       san diego    CA
# 345            gun  59.0      M    W           chino    CA
# 1587       unarmed  36.0      M    W         bel air    MD
# 1646       hatchet  25.0      F    W     lake hallie    WI
# 274            gun  33.0      M    W           omaha    NE
# 483            gun  53.0      M    W        lakeland    FL
# 1763           gun  29.0      M  NaN         hanover    NM
# 1155       machete  37.0      M    H        whittier    CA
# 723          knife  58.0      M    W           tulsa    OK
# 1917       vehicle  38.0      M    W      willoughby    OH
# 1125       vehicle  25.0      M    B          dayton    OH
# 674          knife  37.0      M    W         vallejo    CA
# 516            gun  58.0      M    W         deltona    FL
# 1359           gun  31.0      M    W      cape coral    FL
# 1305         knife  26.0      M    H          rialto    CA
# 214            gun  43.0      M    B       baltimore    MD
# 763            gun  22.0      M    H           miami    FL
# 829     toy weapon  21.0      M    B      long beach    CA
# 1878  undetermined  41.0      M    W       fair oaks    CA
# 2122       vehicle  23.0      M    B          euclid    OH
# 2188           gun  34.0      M    W          tiffin    OH
# 1959           gun  59.0      M    W          naples    ME
# 1627           gun  29.0      M    W        redlands    CA
# 310        vehicle  32.0      M    H         houston    TX
#
#       signs_of_mental_illness  threat_level         flee  body_camera  \
# 1791                    False         other  Not fleeing         True
# 1628                     True         other  Not fleeing        False
# 624                     False        attack  Not fleeing        False
# 2106                    False         other          Car        False
# 1093                    False         other  Not fleeing        False
# 1216                    False         other  Not fleeing        False
# 328                     False        attack  Not fleeing        False
# 857                      True        attack  Not fleeing        False
# 1421                    False        attack  Not fleeing        False
# 1293                    False        attack  Not fleeing        False
# 1906                     True         other  Not fleeing        False
# 2175                    False         other          Car        False
# 46                      False        attack  Not fleeing        False
# 368                      True        attack  Not fleeing        False
# 1882                    False        attack        Other        False
# 4                       False        attack          Car        False
# 1355                    False         other          Car        False
# 1660                    False        attack  Not fleeing        False
# 1449                     True        attack  Not fleeing        False
# 1650                    False         other          Car         True
# 1537                     True        attack         Foot        False
# 1675                    False        attack  Not fleeing        False
# 309                     False        attack  Not fleeing        False
# 238                     False         other  Not fleeing        False
# 2237                     True        attack  Not fleeing        False
# 1101                     True         other  Not fleeing        False
# 881                      True        attack  Not fleeing         True
# 345                     False         other          Car        False
# 1587                     True         other  Not fleeing        False
# 1646                     True         other  Not fleeing        False
# 274                      True        attack         Foot        False
# 483                     False        attack  Not fleeing        False
# 1763                    False  undetermined  Not fleeing        False
# 1155                    False         other  Not fleeing        False
# 723                     False         other          NaN        False
# 1917                    False  undetermined          Car        False
# 1125                    False        attack          Car        False
# 674                      True         other  Not fleeing        False
# 516                      True        attack  Not fleeing        False
# 1359                    False         other          Car        False
# 1305                    False        attack  Not fleeing        False
# 214                     False        attack  Not fleeing        False
# 763                     False        attack  Not fleeing        False
# 829                     False         other  Not fleeing        False
# 1878                    False        attack         Foot        False
# 2122                    False         other          NaN         True
# 2188                    False        attack  Not fleeing        False
# 1959                    False        attack  Not fleeing        False
# 1627                    False        attack  Not fleeing        False
# 310                     False        attack          Car        False
#
#           city_and_state            county_name
# 1791    rush springs, OK           Grady County
# 1628          lowell, MA       Middlesex County
# 624      san antonio, TX           Bexar County
# 2106     floral city, FL          Citrus County
# 1093     chattanooga, TN        Hamilton County
# 1216        santa fe, NM        Santa Fe County
# 328          orlando, FL          Orange County
# 857           marion, IL      Williamson County
# 1421          celina, OH          Mercer County
# 1293         wilhoit, AZ         Yavapai County
# 1906          irvine, CA          Orange County
# 2175      bellflower, CA     Los Angeles County
# 46          columbus, OH        Franklin County
# 368         new city, NY        Rockland County
# 1882     garden city, ID             Ada County
# 4            wichita, KS        Sedgwick County
# 1355      carmichael, CA      Sacramento County
# 1660        mableton, GA            Cobb County
# 1449       camarillo, CA         Ventura County
# 1650            noma, FL          Holmes County
# 1537  rancho cordova, CA      Sacramento County
# 1675     westminster, CO           Adams County
# 309          houston, TX          Harris County
# 238          phoenix, AZ        Maricopa County
# 2237            rowe, NM      San Miguel County
# 1101         seattle, WA            King County
# 881        san diego, CA       San Diego County
# 345            chino, CA  San Bernardino County
# 1587         bel air, MD         Harford County
# 1646     lake hallie, WI        Chippewa County
# 274            omaha, NE         Douglas County
# 483         lakeland, FL            Polk County
# 1763         hanover, NM           Grant County
# 1155        whittier, CA     Los Angeles County
# 723            tulsa, OK           Tulsa County
# 1917      willoughby, OH            Lake County
# 1125          dayton, OH      Montgomery County
# 674          vallejo, CA          Solano County
# 516          deltona, FL         Volusia County
# 1359      cape coral, FL             Lee County
# 1305          rialto, CA  San Bernardino County
# 214        baltimore, MD  Baltimore City County
# 763            miami, FL      Miami-Dade County
# 829       long beach, CA     Los Angeles County
# 1878       fair oaks, CA      Sacramento County
# 2122          euclid, OH        Cuyahoga County
# 2188          tiffin, OH          Seneca County
# 1959          naples, ME      Cumberland County
# 1627        redlands, CA  San Bernardino County
# 310          houston, TX          Harris County

# %%
# popo2 = popo2.drop(labels = 'county_and_state', axis = 1)
popo2['county_and_state'] = popo2['county_name'] + ', ' + popo2['state']

# %%
popo2.head(20)
# Out:
#       id                     name      date   manner_of_death       armed  \
# 0      3               Tim Elliot  02/01/15              shot         gun
# 1      4         Lewis Lee Lembke  02/01/15              shot         gun
# 2    890     Phyllis Ilene Jepsen  02/10/15              shot       knife
# 3      5       John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 4    765          Nicholas Garner  22/08/15              shot     vehicle
# 5   1843         Caleb J. Douglas  01/09/16              shot         gun
# 6   2437           Kevin C. Perry  18/03/17              shot         gun
# 7      8          Matthew Hoffman  04/01/15              shot  toy weapon
# 8    182      Amilcar Perez-Lopez  26/02/15              shot       knife
# 9    221              Alice Brown  17/03/15              shot     vehicle
# 10   922          Herbert Benitez  15/10/15              shot         gun
# 11   998      Javier Lopez Garcia  11/11/15              shot         gun
# 12  1052              Mario Woods  02/12/15              shot       knife
# 13  1443             Luis Gongora  07/04/16              shot       knife
# 14  1548  Jessica Nelson-Williams  19/05/16              shot     unarmed
# 15  1970       Nicholas McWherter  14/10/16              shot         gun
# 16  2556         Nicholas Flusche  03/05/17              shot       knife
# 17  2603                 John Eno  23/05/17              shot         gun
# 18     9        Michael Rodriguez  04/01/15              shot    nail gun
# 19  1312              Luke Miller  25/02/16              shot         gun
#
#      age gender race           city state  signs_of_mental_illness  \
# 0   53.0      M    A        shelton    WA                     True
# 1   47.0      M    W          aloha    OR                    False
# 2   55.0      F    W          aloha    OR                     True
# 3   23.0      M    H        wichita    KS                    False
# 4   26.0      M    W        wichita    KS                    False
# 5   18.0      M    W        wichita    KS                    False
# 6   25.0      M    W        wichita    KS                    False
# 7   32.0      M    W  san francisco    CA                     True
# 8   21.0      M    H  san francisco    CA                    False
# 9   24.0      F    W  san francisco    CA                     True
# 10  27.0      M    H  san francisco    CA                    False
# 11  25.0      M    H  san francisco    CA                    False
# 12  26.0      M    B  san francisco    CA                    False
# 13  45.0      M    H  san francisco    CA                    False
# 14  29.0      F    B  san francisco    CA                    False
# 15  26.0      M    W  san francisco    CA                     True
# 16  26.0      M    W  san francisco    CA                    False
# 17  59.0      M    W  san francisco    CA                    False
# 18  39.0      M    H          evans    CO                    False
# 19  37.0      M    W          evans    CO                    False
#
#     threat_level         flee  body_camera     city_and_state  \
# 0         attack  Not fleeing        False        shelton, WA
# 1         attack  Not fleeing        False          aloha, OR
# 2          other  Not fleeing        False          aloha, OR
# 3          other  Not fleeing        False        wichita, KS
# 4         attack          Car        False        wichita, KS
# 5          other          Car         True        wichita, KS
# 6         attack  Not fleeing        False        wichita, KS
# 7         attack  Not fleeing        False  san francisco, CA
# 8          other  Not fleeing        False  san francisco, CA
# 9          other  Not fleeing        False  san francisco, CA
# 10        attack  Not fleeing        False  san francisco, CA
# 11        attack  Not fleeing        False  san francisco, CA
# 12         other  Not fleeing        False  san francisco, CA
# 13         other  Not fleeing        False  san francisco, CA
# 14  undetermined          Car        False  san francisco, CA
# 15        attack  Not fleeing        False  san francisco, CA
# 16        attack  Not fleeing         True  san francisco, CA
# 17         other  Not fleeing        False  san francisco, CA
# 18        attack  Not fleeing        False          evans, CO
# 19        attack         Foot         True          evans, CO
#
#              county_name          county_and_state
# 0           Mason County          Mason County, WA
# 1      Washington County     Washington County, OR
# 2      Washington County     Washington County, OR
# 3        Sedgwick County       Sedgwick County, KS
# 4        Sedgwick County       Sedgwick County, KS
# 5        Sedgwick County       Sedgwick County, KS
# 6        Sedgwick County       Sedgwick County, KS
# 7   San Francisco County  San Francisco County, CA
# 8   San Francisco County  San Francisco County, CA
# 9   San Francisco County  San Francisco County, CA
# 10  San Francisco County  San Francisco County, CA
# 11  San Francisco County  San Francisco County, CA
# 12  San Francisco County  San Francisco County, CA
# 13  San Francisco County  San Francisco County, CA
# 14  San Francisco County  San Francisco County, CA
# 15  San Francisco County  San Francisco County, CA
# 16  San Francisco County  San Francisco County, CA
# 17  San Francisco County  San Francisco County, CA
# 18           Weld County           Weld County, CO
# 19           Weld County           Weld County, CO

# %%
shootings_by_county = pd.DataFrame(popo2['county_and_state'].value_counts())

# %%
shootings_by_county = shootings_by_county.reset_index().rename(columns={'index': 'County_and_State', 'county_and_state': 'num_shootings'})

# %%
shootings_by_county.head()
# Out:
#             County_and_State  num_shootings
# 0     Los Angeles County, CA            106
# 1        Maricopa County, AZ             65
# 2            Cook County, IL             33
# 3          Harris County, TX             32
# 4  San Bernardino County, CA             30

# %%
for index, row in shootings_by_county.iterrows():
    if 'City' in row.County_and_State.split():
        print(index, row.County_and_State)
# Out:
# 50 Baltimore City County, MD
# 58 Norfolk City County, VA
# 110 Richmond City County, VA
# 206 Virginia Beach City County, VA
# 232 Portsmouth City County, VA
# 250 Newport News City County, VA
# 291 Chesapeake City County, VA
# 298 Carson City County, NV
# 358 Harrisonburg City County, VA
# 359 Roanoke City County, VA
# 457 Hopewell City County, VA
# 533 Emporia City County, VA
# 577 Fredericksburg City County, VA
# 613 Suffolk City County, VA
# 684 Winchester City County, VA
# 697 Falls Church City County, VA
# 767 Alexandria City County, VA

# %%
shootings_by_county.set_value(index = 298, col = 'County_and_State', 
                              value = 'Carson City County, NV')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                County_and_State  num_shootings
# 0        Los Angeles County, CA            106
# 1           Maricopa County, AZ             65
# 2               Cook County, IL             33
# 3             Harris County, TX             32
# 4     San Bernardino County, CA             30
# 5              Clark County, NV             28
# 6          Riverside County, CA             27
# 7         Miami-Dade County, FL             23
# 8             Orange County, CA             23
# 9          San Diego County, CA             22
# 10            Dallas County, TX             22
# 11           Tarrant County, TX             20
# 12             Bexar County, TX             20
# 13       Santa Clara County, CA             19
# 14             Adams County, CO             19
# 15              Kern County, CA             18
# 16           Alameda County, CA             18
# 17          Franklin County, OH             18
# 18          Oklahoma County, OK             17
# 19              King County, WA             17
# 20            Travis County, TX             16
# 21        Sacramento County, CA             16
# 22           Jackson County, MO             16
# 23              Pima County, AZ             15
# 24            Marion County, IN             15
# 25        Bernalillo County, NM             14
# 26            Fresno County, CA             14
# 27             Tulsa County, OK             13
# 28            Denver County, CO             11
# 29         Milwaukee County, WI             11
# ..                          ...            ...
# 755          Jackson County, OH              1
# 756         Anderson County, TX              1
# 757          Raleigh County, WV              1
# 758           Ingham County, MI              1
# 759            Dewey County, OK              1
# 760           Carter County, TN              1
# 761         Fillmore County, MN              1
# 762         McIntosh County, OK              1
# 763           Bonner County, ID              1
# 764       Jo Daviess County, IL              1
# 765          Kendall County, TX              1
# 766         Sullivan County, NH              1
# 767  Alexandria City County, VA              1
# 768       St. Landry County, LA              1
# 769             Polk County, TX              1
# 770           Upshur County, TX              1
# 771            Henry County, AL              1
# 772       Beaverhead County, MT              1
# 773            Bryan County, OK              1
# 774             Park County, MT              1
# 775          Clayton County, GA              1
# 776         Pontotoc County, OK              1
# 777          Cameron County, TX              1
# 778            Grant County, AR              1
# 779         Williams County, OH              1
# 780           Elmore County, AL              1
# 781           Nelson County, KY              1
# 782          Bedford County, TN              1
# 783          Douglas County, IL              1
# 784         Okmulgee County, OK              1
#
# [785 rows x 2 columns]

# %%
# Rename this column for merging later
shootings_by_county.rename(columns={'County_and_State': 'County'}, inplace=True)

# %%
# Send it to a pickle
shootings_by_county.to_pickle('data/shootings_by_county_state.pkl')

# %%
shootings_by_county.head(60)
# Out:
#                              County  num_shootings
# 0            Los Angeles County, CA            106
# 1               Maricopa County, AZ             65
# 2                   Cook County, IL             33
# 3                 Harris County, TX             32
# 4         San Bernardino County, CA             30
# 5                  Clark County, NV             28
# 6              Riverside County, CA             27
# 7             Miami-Dade County, FL             23
# 8                 Orange County, CA             23
# 9              San Diego County, CA             22
# 10                Dallas County, TX             22
# 11               Tarrant County, TX             20
# 12                 Bexar County, TX             20
# 13           Santa Clara County, CA             19
# 14                 Adams County, CO             19
# 15                  Kern County, CA             18
# 16               Alameda County, CA             18
# 17              Franklin County, OH             18
# 18              Oklahoma County, OK             17
# 19                  King County, WA             17
# 20                Travis County, TX             16
# 21            Sacramento County, CA             16
# 22               Jackson County, MO             16
# 23                  Pima County, AZ             15
# 24                Marion County, IN             15
# 25            Bernalillo County, NM             14
# 26                Fresno County, CA             14
# 27                 Tulsa County, OK             13
# 28                Denver County, CO             11
# 29             Milwaukee County, WI             11
# 30         San Francisco County, CA             11
# 31  District of Columbia County, DC             11
# 32           Mecklenburg County, NC             11
# 33                 Duval County, FL             11
# 34              New York County, NY             10
# 35           San Joaquin County, CA             10
# 36               Volusia County, FL             10
# 37                 Wayne County, MI             10
# 38             Baltimore County, MD             10
# 39                Washoe County, NV              9
# 40              Cuyahoga County, OH              9
# 41                Orange County, FL              9
# 42          Hillsborough County, FL              9
# 43                Fulton County, GA              9
# 44                Pierce County, WA              9
# 45          Philadelphia County, PA              9
# 46               Brevard County, FL              8
# 47                Mohave County, AZ              8
# 48            Stanislaus County, CA              8
# 49             Multnomah County, OR              8
# 50        Baltimore City County, MD              8
# 51               Douglas County, NE              8
# 52      East Baton Rouge County, LA              8
# 53            Washington County, OR              7
# 54             Jefferson County, AL              7
# 55               Orleans County, LA              7
# 56               El Paso County, TX              7
# 57               Larimer County, CO              7
# 58          Norfolk City County, VA              7
# 59                 Pinal County, AZ              7
